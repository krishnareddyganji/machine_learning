# %%
import pandas as pd

scores = { 'name ': ['krishna','kittu'],
            'clas' : ['c1','c2'],
            'age' : [20,21] }

# %%
df = pd.DataFrame(scores)

# %%
df
# Out:
#      name  clas  age
# 0  krishna   c1   20
# 1    kittu   c2   21

# %%
df['age']
# Out:
# 0    20
# 1    21
# Name: age, dtype: int64

# %%
df[df['age']>20]
# Out:
#    name  clas  age
# 1  kittu   c2   21

# %%
df.shape
# Out:
# (2, 3)

# %%
df.dtypes
# Out:
# name     object
# clas     object
# age       int64
# dtype: object

# %%
df.to_csv('data_info',index=False)

# %%
cars
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cars
#
# NameError: name 'cars' is not defined

# %%
cars.dtypes

# %%
cars.head(20)

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/user/datasets_ml/data_info.csv")

# %%
df

# %%
df = pd.read_csv("/home/user/datasets_ml/Car_sales.csv")

# %%
df

# %%
df.head(100)

# %%
df.dtypes

# %%
df.isnull()

# %%
df.isna()

# %%
    df.interpolate()

# %%
data = df.where(pd.notnull(df))

# %%
data

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
df.sample(2)
# Out:
#      name  clas  age
# 0  krishna   c1   20
# 1    kittu   c2   21

# %%
df = pd.read_csv("/home/user/datasets_ml/Car_sales.csv")

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            1
# Horsepower             1
# Wheelbase              1
# Width                  2
# Length                 1
# Curb weight            1
# Fuel capacity          1
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
df['Vehicle type'].unique()
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %%
def type (x):
    if x == "Passenger " : return 1
    if x == "Car" : return 2

# %%
df['Vehicle type']= df['Vehicle type'].apply(type)

# %%
df['Vehicle type']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 152   NaN
# 153   NaN
# 154   NaN
# 155   NaN
# 156   NaN
# Name: Vehicle type, Length: 157, dtype: float64

# %%
df.iloc[:,1]
# Out:
# 0      Integra
# 1      TL
# 2      CL
# 3      RL
# 4      A4
#              ...
# 152    V40
# 153    S70
# 154    V70
# 155    C70
# 156    S80
# Name: Model, Length: 157, dtype: object

# %%
df.iloc[ : ,0:5]
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#      Vehicle type
# ...

# %%
df1 = df.select_dtypes(include=['int64','float64'])

# %%
df1
# Out:
#      Sales in thousands  Vehicle type  Engine size  Horsepower  Wheelbase  \
# 0                16.919           NaN          1.8       140.0      101.2
# 1                39.384           NaN          3.2       225.0      108.1
# 2                14.114           NaN          3.2       225.0      106.9
# 3                 8.588           NaN          3.5       210.0      114.6
# 4                20.397           NaN          1.8       150.0      102.6
# ..                  ...           ...          ...         ...        ...
# 152               3.545           NaN          1.9       160.0      100.5
# 153              15.245           NaN          2.4       168.0      104.9
# 154              17.531           NaN          2.4       168.0      104.9
# 155               3.493           NaN          2.3       236.0      104.9
# 156              18.969           NaN          2.9       201.0      109.9
#
#      Width  Length  Fuel capacity
# 0     67.3   172.4           13.2
# ...

# %%
df.describe()
# Out:
#        Sales in thousands  Vehicle type  Engine size  Horsepower   Wheelbase  \
# count          157.000000          41.0   156.000000  156.000000  156.000000
# mean            52.998076           2.0     3.060897  185.948718  107.487179
# std             68.029422           0.0     1.044653   56.700321    7.641303
# min              0.110000           2.0     1.000000   55.000000   92.600000
# 25%             14.114000           2.0     2.300000  149.500000  103.000000
# 50%             29.450000           2.0     3.000000  177.500000  107.000000
# 75%             67.956000           2.0     3.575000  215.000000  112.200000
# max            540.561000           2.0     8.000000  450.000000  138.700000
#
#             Width      Length  Fuel capacity
# count  155.000000  156.000000     156.000000
# mean    71.129032  187.343590      17.951923
# std      3.453080   13.431754       3.887921
# min     62.600000  149.400000      10.300000
# 25%     68.400000  177.575000      15.800000
# ...

# %%
df1.describe()
# Out:
#        Sales in thousands  Vehicle type  Engine size  Horsepower   Wheelbase  \
# count          157.000000          41.0   156.000000  156.000000  156.000000
# mean            52.998076           2.0     3.060897  185.948718  107.487179
# std             68.029422           0.0     1.044653   56.700321    7.641303
# min              0.110000           2.0     1.000000   55.000000   92.600000
# 25%             14.114000           2.0     2.300000  149.500000  103.000000
# 50%             29.450000           2.0     3.000000  177.500000  107.000000
# 75%             67.956000           2.0     3.575000  215.000000  112.200000
# max            540.561000           2.0     8.000000  450.000000  138.700000
#
#             Width      Length  Fuel capacity
# count  155.000000  156.000000     156.000000
# mean    71.129032  187.343590      17.951923
# std      3.453080   13.431754       3.887921
# min     62.600000  149.400000      10.300000
# 25%     68.400000  177.575000      15.800000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.regplot(x='Width',y='Length',data=df)
plt.show()

# %%
sns.boxplot(x='Width',y='Manufacturer',data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
plt.show()

# %%
df.head(20)
# Out:
#      Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0   Acura          Integra                        16.919               16.36
# 1   Acura          TL                             39.384              19.875
# 2   Acura          CL                             14.114              18.225
# 3   Acura          RL                              8.588              29.725
# 4   Audi           A4                             20.397              22.255
# 5   Audi           A6                             18.780              23.555
# 6   Audi           A8                              1.380                  39
# 7   BMW            323i                           19.747                   .
# 8   BMW            328i                            9.231              28.675
# 9   BMW            528i                           17.527              36.125
# 10  Buick          Century                        91.561              12.475
# ...

# %%
df.head().transpose()
# Out:
#                                      0                  1                  2  \
# Manufacturer             Acura              Acura              Acura
# Model                Integra            TL                 CL
# Sales in thousands              16.919             39.384             14.114
# 4-year resale value              16.36             19.875             18.225
# Vehicle type                       NaN                NaN                NaN
# Price in thousands                21.5               28.4                  .
# Engine size                        1.8                3.2                3.2
# Horsepower                       140.0              225.0              225.0
# Wheelbase                        101.2              108.1              106.9
# Width                             67.3               70.3               70.6
# Length                           172.4              192.9              192.0
# ...

# %%
df.Width.value_counts()
# Out:
# Width
# 66.7    6
# 68.3    5
# 70.3    5
# 74.4    5
# 72.7    5
#        ..
# 67.4    1
# 73.4    1
# 76.1    1
# 73.5    1
# 68.2    1
# Name: count, Length: 78, dtype: int64

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.Width.value_counts(normalize = True)*100
# Out:
# Width
# 66.7    3.870968
# 68.3    3.225806
# 70.3    3.225806
# 74.4    3.225806
# 72.7    3.225806
#           ...
# 67.4    0.645161
# 73.4    0.645161
# 76.1    0.645161
# 73.5    0.645161
# 68.2    0.645161
# Name: proportion, Length: 78, dtype: float64

# %%
df['difference'] = df['Width']-df['Length']

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df[['Width','Length','difference']]
# Out:
#      Width  Length  difference
# 0     67.3   172.4      -105.1
# 1     70.3   192.9      -122.6
# 2     70.6   192.0      -121.4
# 3     71.4   196.6      -125.2
# 4     68.2   178.0      -109.8
# ..     ...     ...         ...
# 152   67.6   176.6      -109.0
# 153   69.3   185.9      -116.6
# 154   69.3   186.2      -116.9
# 155   71.5   185.7      -114.2
# 156   72.1   189.8      -117.7
#
# [157 rows x 3 columns]

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.groupby('Manufacturer')['Sales in thousands'].mean()
# Out:
# Manufacturer
# Acura             19.751250
# Audi              13.519000
# BMW               15.501667
# Buick             60.504750
# Cadillac          22.435600
# Chevrolet         61.596111
# Chrysler          28.817286
# Dodge             82.740818
# Ford             183.875909
# Honda            118.534800
# Hyundai           45.775333
# Infiniti          23.713000
# Jaguar            15.467000
# Jeep              97.717667
# Lexus             17.807167
# Lincoln           28.544667
# Mercedes-Benz     13.013889
# Mercury           39.666500
# Mitsubishi        25.842143
# Nissan            57.090714
# Oldsmobile        29.831500
# Plymouth          16.000250
# Pontiac           61.755667
# Porsche            4.042667
# Saab              10.653000
# Saturn            33.770000
# Subaru            40.067500
# Toyota            82.245000
# Volkswagen        34.868667
# Volvo             12.623333
# Name: Sales in thousands, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.Manufacturer = le.fit_transform(df.Manufacturer)

# %%
df.Model = le.fit_transform(df.Model)

# %%
df.head(40)
# Out:
#     Manufacturer  Model  Sales in thousands 4-year resale value  Vehicle type  \
# 0              0     79              16.919               16.36           NaN
# 1              0    143              39.384              19.875           NaN
# 2              0     25              14.114              18.225           NaN
# 3              0    115               8.588              29.725           NaN
# 4              1      8              20.397              22.255           NaN
# 5              1      9              18.780              23.555           NaN
# 6              1     10               1.380                  39           NaN
# 7              2      3              19.747                   .           NaN
# 8              2      4               9.231              28.675           NaN
# 9              2      7              17.527              36.125           NaN
# 10             3     38              91.561              12.475           NaN
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
x = df.drop(['Model'],axis = 'columns')
x
y = df['Sales in thousands']
y
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales in thousands, Length: 157, dtype: float64

# %%
y
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales in thousands, Length: 157, dtype: float64

# %%
x
# Out:
#      Manufacturer  Sales in thousands 4-year resale value  Vehicle type  \
# 0               0              16.919               16.36           NaN
# 1               0              39.384              19.875           NaN
# 2               0              14.114              18.225           NaN
# 3               0               8.588              29.725           NaN
# 4               1              20.397              22.255           NaN
# ..            ...                 ...                 ...           ...
# 152            29               3.545                   .           NaN
# 153            29              15.245                   .           NaN
# 154            29              17.531                   .           NaN
# 155            29               3.493                   .           NaN
# 156            29              18.969                   .           NaN
#
#     Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df = df.dropna(axis=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.fit(x,y)
#
# NameError: name 'model' is not defined

# %%
df.describe()

# %%
df.info()

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
df.info()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %% [markdown]
# model.fit(x,y)

# %%
LinearRegression()

# %%
df

# %%
    newd = np.array([[50,34,79]])

# %%
newd
# Out:
# array([[50, 34, 79]])

# %%
car = pd.read_csv('car_price.csv')

# %%
car
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
car.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Doors', 'Owner_Count', 'Price'],
#       dtype='object')

# %%
df =car.sort_values('Engine_Size')

# %%
df['Engine_Size']
# Out:
# 4811    1.0
# 4766    1.0
# 4783    1.0
# 9895    1.0
# 5445    1.0
#        ...
# 7196    5.0
# 9575    5.0
# 2691    5.0
# 6205    5.0
# 3364    5.0
# Name: Engine_Size, Length: 10000, dtype: float64

# %%
df['Engine_Size'].tail()
# Out:
# 7196    5.0
# 9575    5.0
# 2691    5.0
# 6205    5.0
# 3364    5.0
# Name: Engine_Size, dtype: float64

# %%
sns.boxplot(data=car,x='Engine_Size')
# Out:
# <Axes: xlabel='Engine_Size'>

# %%
import pandas as pd

# %%
val = car[['Year','Engine_Size','Doors']]

# %%
val
# Out:
#       Year  Engine_Size  Doors
# 0     2020          4.2      3
# 1     2012          2.0      2
# 2     2020          4.2      4
# 3     2023          2.0      2
# 4     2003          2.6      3
# ...    ...          ...    ...
# 9995  2004          3.7      2
# 9996  2002          1.4      2
# 9997  2010          3.0      5
# 9998  2002          1.4      4
# 9999  2001          2.1      3
#
# [10000 rows x 3 columns]
